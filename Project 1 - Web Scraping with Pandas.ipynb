# %% [markdown]
# # Web scraping :

# %% [markdown]
# ##### Web scraping is an automated method to extract large amounts of data from websites.

# %%
import pandas as pd

# %% [markdown]
# # Read a .csv from a URL with Pandas

# %% [markdown]
# ##### Target website: https://www.football-data.co.uk/data.php

# %%
# reading 1 csv file from the website
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
df_premire21 = df_premier21.rename(columns={'Date':'date',
                                   'Hometown':'home_town',
                                   'AwayTeam':'away_team',
                                   'FTGH':'home_goals',
                                   'FTGH':'away_goals'})

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %% [markdown]
# # Read .csv from Multiple URLs with Pandas

# %% [markdown]
# ##### https://www.football-data.co.uk/mmz4281/2122/E0.csv

# %% [markdown]
# #### Link: root + season + league

# %%
##### link structure
"https://www.football-data.co.uk/mmz4281/" + "2122" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2122/E0.csv'

# %%
# create a root variable
root="https://www.football-data.co.uk/mmz4281/"

# %%
import pandas as pd

# %% [markdown]
# # Multiple leagues

# %% [markdown]
# ##### https://www.football-data.co.uk/mmz4281/2122/EO.csv
# ##### https://www.football-data.co.uk/mmz4281/2122/E1.csv
# ##### https://www.football-data.co.uk/mmz4281/2122/E2.csv
# ##### https://www.football-data.co.uk/mmz4281/2122/EC.csv

# %%
# Creating a list of leagues
leagues = ['E0', 'E2', 'E3']

#frames is a list used to store multiple DataFrames.
frames = [] 

# looping through leagues, read multiple csv and append it into a list
for league in leagues:
    df = pd.read_csv(root + "2122" + "/" + league + ".csv")
    frames.append(df)

# %%
len(frames)
# Out:
# 3

# %%
frames[2].head(3)
# Out:
#   Div        Date   Time      HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E3  07/08/2021  15:00      Carlisle  Colchester     0     0   D     0
# 1  E3  07/08/2021  15:00        Exeter    Bradford     0     0   D     0
# 2  E3  07/08/2021  15:00  Forest Green      Sutton     2     1   H     1
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.57 -0.25      1.75      2.05   1.78   2.13     1.82
# 1     0  ...     1.65  0.00      1.80      2.05   1.79   2.12     1.87
# 2     0  ...     1.60 -0.25      1.98      1.83   1.93   1.95     2.03
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.13     1.75     2.08
# 1     2.12     1.80     2.03
# 2     1.99     1.91     1.90
#
# [3 rows x 106 columns]

# %% [markdown]
# # Multiple Seasons

# %%
leagues = ['E0', 'E2', 'E3']

Frames = []

# loop through range of seasons and insert new column
for league in leagues:
    for season in range(15,21): #range of seasons
        df=pd.read_csv(root + str(season) + str(season+1) + "/" + league + ".csv")
#       df['season'] = season
       df.insert(1, 'season', season)
       frames.append(df)
# Out:
#   File <string>:10
#     df.insert(1, 'season', season)
#                                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
leagues = ['E0', 'E2', 'E3']

frames = []

# loop through range of seasons and insert new column
for league in leagues:
    for season in range(15, 21):   # range of seasons
        
        df = pd.read_csv(
            root + str(season) + str(season + 1) + "/" + league + ".csv"
        )

        # insert new column
        df.insert(1, 'season', season)

        # append dataframe into list
        frames.append(df)

# %%
len(frames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 len(frames)
#
# NameError: name 'frames' is not defined

# %%
frames(17)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 frames(17)
#
# NameError: name 'frames' is not defined

# %% [markdown]
# # Organize All The Data in a Dictionary

# %%
# create a dictionary with original name of league as key
dict_countries = {
    'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
    'German Bundesliga':'D1',
    'English Premier league':'E0', 'English League 1':'E2','English League 2':'E3'
    }

# %%
# get a dictionary element
dict_countries['German Bundesliga']
# Out:
# 'D1'

# %%
dict_historical_data = {}

# looping through key elements
for league in dict_countries:
    frames = [] # one dataframe per league
    for season in range(15,21):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1 , 'season', season)
        frames(
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       3 # looping through key elements
#       4 for league in dict_countries:
#       5     frames = [] # one dataframe per league
#       6     for season in range(15,21):
# ----> 7         df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
#
# NameError: name 'root' is not defined
